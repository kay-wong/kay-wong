# %%
import requests
import pandas as pd

# %%
DewanRakyatID = '53633b5a19ee29270d8a9ecf'
url = 'http://api.popit.sinarproject.org/en/organizations/'+ DewanRakyatID+ "/?minify=True"
r = requests.get(url).json()['result'] 
#Get membership IDs of all current and ex-members of Dewan Rakyat
membershipIDs = r['memberships']

# %% [markdown]
# ### Getting all current Members of Parliament
#
# All members without an end date for their post are considered as current members. We'll write a simple loop through our members list to extract all the current parliamentarians.

# %%
currentMembers = []

for membership_id in membershipIDs:
        url = 'http://api.popit.sinarproject.org/en/memberships/'+ membership_id
        member = requests.get(url).json()['result']

        #Get current members
        end_date = member['end_date']
        
        if end_date: #has end date, ex member
            pass    
        else: #current member
            currentMembers.append(member)

# %% [markdown]
# Turning our dictionary object into a Pandas dataframe, with the keys of the response payload as the columns for our new dataframe:

# %%
currMems = pd.Series(currentMembers).to_dict()
df = pd.DataFrame.from_dict(currMems, orient = 'index')
df.head() #Preview

# %% [markdown]
# ### Expand contents of nested columns
# Due to the nested nature of the API response, we'll flatten the contents of a few select columns by first extracting the contents of the Persons, Posts and On Behalf Of columns which contains nested dictionaries, and converting it into new dataframes:

# %%
personsdf = pd.DataFrame.from_dict(df['person'].to_dict(), orient = 'index')
personsdf.drop('id', axis=1, inplace=True)  #drop to avoid overlap with alread existing persons_id in df

#Get post df
postdf = pd.DataFrame.from_dict(df['post'].to_dict(), orient = 'index')

#Get on_behalf_of df
df['on_behalf_of'] = df['on_behalf_of'].apply(lambda x: {} if pd.isnull(x) else x)
on_behalf_of_df = pd.DataFrame.from_dict(df['on_behalf_of'].to_dict(), orient = 'index')

# %% [markdown]
# And then joining the extracted dataframes with our original dataframe to give us a flat representation that combines information from all classes. This is similar to what was demonstrated in [Working with Popit API and Pandas](https://github.com/kay-wong/kay-wong/blob/master/Working%2Bwith%2BPopit%2BAPI%2Band%2BPandas.ipynb).

# %%
personsdf.columns = ['person_'+colName for colName in personsdf.columns] #add 'person' suffix to column names of personsdf

df =  df.join(personsdf, how = 'outer')
df['post_label'] =  postdf['label']
df['on_behalf_of'] = on_behalf_of_df['name']

# %% [markdown]
# Obtaining the contact details for each MP is less straightforward than what we did earlier for Posts and Persons, as the contacts class has an uneven number of fields, unlike that for posts and persons. For this we will have to apply a getContacts function on each row individually.

# %%
personContacts = personsdf['person_contact_details']
contactKeys  = ['contact_twitter','contact_email', 'contact_cell', 'contact_voice', 'contact_fax', 'contact_address']
    
def getContacts(contact_detail):    
    contacts = {}
    #Initialize contacts dic with fixed number of fields
    contactKeys  = ['contact_twitter','contact_email', 'contact_cell', 'contact_voice', 'contact_fax', 'contact_address']
    contactVals=  [""]*len(contactKeys)
    contacts = dict(zip(contactKeys, contactVals))
    #Update contact values
    for c in contact_detail:
        key = 'contact_'+ c['type']
        if key in contactKeys:
            contacts[key] = c['value']

    return contacts

personContacts = personContacts.apply(getContacts)
personContacts = pd.DataFrame.from_dict(personContacts.to_dict(), orient= 'index')

personContacts.head()

#Join personContacts with our original df
df = df.join(personContacts, how = 'outer')

# %% [markdown]
# ## Analysis of female MPs
# Now we can do some analyses on parliamentarians across different classes.

# %%
#For plotting
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %% [markdown]
# #### Get percentage of women MPs in current Parliament.

# %%
gender_ratio = df['person_gender'].value_counts()
explode = (0, 0.1)  #only "explode" the 'Female' slice
fig1, ax1 = plt.subplots()
ax1.pie(gender_ratio, explode = explode, labels=gender_ratio.keys(), autopct='%1.1f%%',
        shadow=True, startangle=90)

ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# #### A closer examination of female MP entries

# %%
#Get dataframe of female MPs
femaleMPs = df[female]
#Index a few columns to examine
femaleMPs[['person_name', 'person_gender', 'person_national_identity', 'person_birth_date', 'start_date', 'post_label', 'on_behalf_of']]
# Out:
#                        person_name person_gender person_national_identity  \
# 4            Wan Azizah Wan Ismail        Female                    Malay
# 16               Nurul Izzah Anwar        Female                     None
# 17              Teresa Kok Suh Sim        Female                  Chinese
# 26          Mas Ermieyati Samsudin        Female                     None
# 37                   Noraini Ahmad        Female                     None
# 45         Halimah Mohamed Sadique        Female                     None
# 47             Azalina Othman Said        Female                    Malay
# 49             Normala Abdul Samad        Female                     None
# 53                   Teo Nie Ching        Female                  Chinese
# 61     Rosnah Abdul Rashid Shirlin        Female                     None
# 63                 Azizah Mohd Dun        Female                     None
# 71                   Tsen Thau Lin        Female                  Chinese
# 74                  Yap Kain Ching        Female                  Chinese
# 86              Zuraida Kamaruddin        Female                    Malay
# 90                     Rubiah Wang        Female                     None
# 96        Siti Mariah Binti Mahmud        Female                    Malay
# 97                    Nancy Shukri        Female                     None
# 98              Rohani Abdul Karim        Female                     None
# 104          Alice Lau Kiong Yieng        Female                  Chinese
# 106             Norah Abdul Rahman        Female                     None
# 124  Siti Zailah Binti Mohd Yusoff        Female                    Malay
# 148            Kasthuriraani Patto        Female                     None
# 176            Fuziah Binti Salleh        Female                    Malay
# 192             Mastura Mohd Yazid        Female                     None
#
#     person_birth_date  start_date             post_label  \
# 4          1952-12-03  2015-05-08  MP for Permatang Pauh
# 16         1980-11-19  2013-06-24   MP for Lembah Pantai
# 17         1964-03-31  2013-06-24         MP for Seputeh
# 26         1976-11-13  2013-06-24    MP for Masjid Tanah
# 37         1967-11-07  2013-06-24    MP for Parit Sulong
# 45         1962-02-02  2013-06-24        MP for Tenggara
# 47         1963-12-31  2013-06-24       MP for Pengerang
# 49               None  2013-06-24    MP for Pasir Gudang
# 53         1981-01-27  2013-06-24           MP for Kulai
# 61         1972-07-10  2013-06-24           MP for Papar
# 63         1955-03-27  2013-06-24        MP for Beaufort
# 71               None  2013-06-24       MP for Batu Sapi
# 74               None  2013-06-24           MP for Tawau
# 86         1958-03-14  2013-06-24          MP for Ampang
# 90               None  2013-06-24  MP for Kota Samarahan
# 96         1958-02-14  2013-06-24       MP for Kota Raja
# 97         1961-08-05  2013-06-24   MP for Batang Sadong
# 98         1955-01-03  2013-06-24    MP for Batang Lupar
# 104              None  2013-06-24          MP for Lanang
# 106        1959-10-04  2013-06-24   MP for Tanjong Manis
# 124        1963-10-12  2013-06-24  MP for Rantau Panjang
# 148        1979-08-09  2013-06-24      MP for Batu Kawan
# 176              None  2013-06-24         MP for Kuantan
# 192              None  2016-06-18   MP for Kuala Kangsar
#
#                         on_behalf_of
# 4              Parti Keadilan Rakyat
# 16             Parti Keadilan Rakyat
# 17           Democratic Action Party
# 26              UMNO Supreme Council
# 37              UMNO Supreme Council
# 45              UMNO Supreme Council
# 47              UMNO Supreme Council
# 49              UMNO Supreme Council
# 53           Democratic Action Party
# 61              UMNO Supreme Council
# 63              UMNO Supreme Council
# 71        Parti Bersatu Rakyat Sabah
# 74               Parti Bersatu Sabah
# 86             Parti Keadilan Rakyat
# 90   Parti Pesaka Bumiputera Bersatu
# 96               Parti Amanah Negara
# 97   Parti Pesaka Bumiputera Bersatu
# 98   Parti Pesaka Bumiputera Bersatu
# 104          Democratic Action Party
# 106  Parti Pesaka Bumiputera Bersatu
# 124           Parti Islam Semalaysia
# 148          Democratic Action Party
# 176            Parti Keadilan Rakyat
# 192             UMNO Supreme Council

# %% [markdown]
# #### Racial makeup of female MPs of current parliament

# %%
femaleMP_race = femaleMPs['person_national_identity'].value_counts()

fig1, ax2 = plt.subplots()
ax2.pie(femaleMP_race, labels=femaleMP_race.keys(), autopct='%1.1f%%',
        shadow= True, startangle=90)
ax2.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# #### Party makeup of female MPs of current parliament

# %%
femaleMP_party = femaleMPs['on_behalf_of'].value_counts()

fig1, ax3 = plt.subplots()
ax3.pie(femaleMP_party, labels=femaleMP_party.keys(), autopct='%1.1f%%',
        shadow= True, startangle=90)
ax3.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# #### Contact details for all female MPs

# %%
femaleMP_contacts = femaleMPs.filter(regex = r'^contact_')
femaleMPs[['person_name', 'post_label', 'on_behalf_of']].join(femaleMP_contacts, how= 'outer')
# Out:
#                        person_name             post_label  \
# 4            Wan Azizah Wan Ismail  MP for Permatang Pauh
# 16               Nurul Izzah Anwar   MP for Lembah Pantai
# 17              Teresa Kok Suh Sim         MP for Seputeh
# 26          Mas Ermieyati Samsudin    MP for Masjid Tanah
# 37                   Noraini Ahmad    MP for Parit Sulong
# 45         Halimah Mohamed Sadique        MP for Tenggara
# 47             Azalina Othman Said       MP for Pengerang
# 49             Normala Abdul Samad    MP for Pasir Gudang
# 53                   Teo Nie Ching           MP for Kulai
# 61     Rosnah Abdul Rashid Shirlin           MP for Papar
# 63                 Azizah Mohd Dun        MP for Beaufort
# 71                   Tsen Thau Lin       MP for Batu Sapi
# 74                  Yap Kain Ching           MP for Tawau
# 86              Zuraida Kamaruddin          MP for Ampang
# 90                     Rubiah Wang  MP for Kota Samarahan
# 96        Siti Mariah Binti Mahmud       MP for Kota Raja
# 97                    Nancy Shukri   MP for Batang Sadong
# 98              Rohani Abdul Karim    MP for Batang Lupar
# 104          Alice Lau Kiong Yieng          MP for Lanang
# 106             Norah Abdul Rahman   MP for Tanjong Manis
# 124  Siti Zailah Binti Mohd Yusoff  MP for Rantau Panjang
# 148            Kasthuriraani Patto      MP for Batu Kawan
# 176            Fuziah Binti Salleh         MP for Kuantan
# 192             Mastura Mohd Yazid   MP for Kuala Kangsar
#
#                         on_behalf_of contact_twitter   contact_fax  \
# 4              Parti Keadilan Rakyat      drwanaziza  03-7885 0531
# 16             Parti Keadilan Rakyat         n_izzah
# 17           Democratic Action Party       teresakok
# 26              UMNO Supreme Council     emysamsudin
# 37              UMNO Supreme Council
# 45              UMNO Supreme Council
# 47              UMNO Supreme Council         Azalina
# 49              UMNO Supreme Council    normalasamad
# 53           Democratic Action Party     teonieching
# 61              UMNO Supreme Council      Rosnah_ARS
# 63              UMNO Supreme Council   azizahmohddun
# 71        Parti Bersatu Rakyat Sabah
# 74               Parti Bersatu Sabah       maryyapkc
# 86             Parti Keadilan Rakyat           ybz99
# 90   Parti Pesaka Bumiputera Bersatu
# 96               Parti Amanah Negara                   03-51626868
# 97   Parti Pesaka Bumiputera Bersatu     nancyshukri
# 98   Parti Pesaka Bumiputera Bersatu  hjhrohanikarim
# 104          Democratic Action Party        alicelky
# 106  Parti Pesaka Bumiputera Bersatu
# 124           Parti Islam Semalaysia                    09-9551568
# 148          Democratic Action Party   kasthuripatto
# 176            Parti Keadilan Rakyat        fuziah99    09-5137970
# 192             UMNO Supreme Council
#
#                                        contact_address contact_cell  \
# 4    Ibu Pejabat Parti Keadilan Rakyat, A-1-09 Merc...
# 16   No. 1-2 Jalan Pantai Murni 6,  Pantai Dalam,  ...
# 17   28-3a, 4th Floor Sri Desa Entrepreneur's Park ...
# 26   MT 2193 Jalan Taman Bandar Baru, 78300 Masjid ...
# 37   62a Jalan Sepah Puteri 5/24 Kota Damansara 478...
# 45   Kkbpkt Aras 18, No 51 Persiaran Perdana, Presi...
# 47   No 10, Jalan Laksamana 12/1, Seksyen 12, 40000...
# 49   No. 20 Jalan Suria 64 Bandar Sri Alam 81750 Ma...
# 53   No. 21-1 Jalan Tropikal Taman Tropika, 81000 K...
# 61   Kementerian Kerja Raya, Tingkat 5, Blok A Komp...
# 63   Kementerian Pembangunan Wanita, Keluarga Dan M...
# 71   Blok I, House No 4 Taman Likas Jaya 88400 Kota...
# 74   My Edutraining & Consultancy, Tb 291, 2nd Floo...
# 86   Pejabat Parlimen Ampang C02-2, Tkt 3 Garden Ci...  019-3854238
# 90   No. 89, Lorong 22J Taman Desa Ilmu 94300 Kota ...
# 96   No. 34 Jalan Temenggung 1, Taman Sentosa Perda...
# 97   Pusat Khidmat Rakyat P200 Batang Sadong, Tingk...
# 98   Kementerian Pembangunan Wanita, Keluarga Dan M...
# 104            No. 7 Jalan Sebuyau, 96000 Sibu Sarawak
# 106  Suite 2.2, Level 2 Block C Plaza Damansara Jal...
# 124  884b Jalan Bunga Raya Kg. Kubang Chenok 17200 ...
# 148
# 176  No. 8298 Desa D' Firdaus Kg Sg. Merab Tengah 4...  019-2702838
# 192  NO. 2-2 TINGKAT 2, JALAN JELATEK 1, JELATEK BU...
#
#                                          contact_email  \
# 4                                   nonaziza@gmail.com
# 16
# 17
# 26                                 amysudin2@yahoo.com
# 37
# 45                         halimah.sadique@kpkt.gov.my
# 47                                  donhezry@gmail.com
# 49                                  mala1809@yahoo.com
# 53   teoniecheng@gmail.com / teoniecheng.office@gma...
# 61                             rosnahshirlin@yahoo.com
# 63                              azizahdun@kpwkm.gov.my
# 71                          lindatsenthaulin@gmail.com
# 74                                   maryykc@yahoo.com
# 86                        zuraida.kamaruddin@gmail.com
# 90       parlimenp197@gmail.com / rubiahwang@yahoo.com
# 96                              drsitimariah@gmail.com
# 97                            nstcs.training@yahoo.com
# 98   parlimenblupar@yahoo.com / rohani_karim@yahoo....
# 104                               alicelky81@gmail.com
# 106                                 dtknorah@gmail.com
# 124                               sitizailah@gmail.com
# 148                      parlimen46batukawan@gmail.com
# 176                                 fuziah99@gmail.com
# 192                                dmasyazid@gmail.com
#
#                  contact_voice
# 4                 03-7885 0530
# 16                 03-22409475
# 17                 03-79836768
# 26                  06-3846050
# 37                  07-4380666
# 45                 03-88915027
# 47                  07-8953397
# 49                  07-3881735
# 53                 03-95446720
# 61                 03-27714010
# 63                  088-422797
# 71                  089-274320
# 74                  089-756799
# 86   03-42515987 / 03-42705950
# 90                  082-662079
# 96                 03-51619000
# 97                  082-448861
# 98                 03-83231011
# 104                 084-336671
# 106  03-20953006 / 03-20962022
# 124                 09-7916172
# 148                 04-5681639
# 176
# 192                03-42566933
